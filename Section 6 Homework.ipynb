# %%
# P4-Section6-Homework-Dataset.csv
# C:\Users\Admin\Desktop\Python Training

# %%
# import the file and add standard libraries

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
moviedata = pd.read_csv(r'C:\Users\Admin\Desktop\Python Training\P4-Section6-Homework-Dataset.csv', encoding = 'cp1252')

# %%
moviedata.head()
# Out:
#   Day of Week                 Director   Genre        Movie Title  \
# 0      Friday                Brad Bird  action       Tomorrowland
# 1      Friday              Scott Waugh  action     Need for Speed
# 2      Friday           Patrick Hughes  action  The Expendables 3
# 3      Friday  Phil Lord, Chris Miller  comedy     21 Jump Street
# 4      Friday          Roland Emmerich  action   White House Down
#
#   Release Date               Studio Adjusted Gross ($mill)  Budget ($mill)  \
# 0   22/05/2015  Buena Vista Studios                  202.1           170.0
# 1   14/03/2014  Buena Vista Studios                  204.2            66.0
# 2   15/08/2014            Lionsgate                  207.1           100.0
# 3   16/03/2012                 Sony                  208.8            42.0
# 4   28/06/2013                 Sony                  209.7           150.0
#
#   Gross ($mill)  IMDb Rating  MovieLens Rating Overseas ($mill)  Overseas%  \
# ...

# %%
moviedata.columns
# Out:
# Index(['Day of Week', 'Director', 'Genre', 'Movie Title', 'Release Date',
#        'Studio', 'Adjusted Gross ($mill)', 'Budget ($mill)', 'Gross ($mill)',
#        'IMDb Rating', 'MovieLens Rating', 'Overseas ($mill)', 'Overseas%',
#        'Profit ($mill)', 'Profit%', 'Runtime (min)', 'US ($mill)',
#        'Gross % US'],
#       dtype='object')

# %%
moviedata.columns = ['DayofWeek', 'Director', 'Genre', 'MovieTitle', 'ReleaseDate',
       'Studio', 'AdjustedGrossMillions', 'BudgetMillions', 'GrossMillions',
       'IMDbRating', 'MovieLensRating', 'OverseasMillions', 'OverseasPercent',
       'ProfitMillions', 'ProfitPercent', 'RuntimeMinutes', 'USMillions',
       'GrossPrecentUS']

# %%
moviedata.head()
# Out:
#   DayofWeek                 Director   Genre         MovieTitle ReleaseDate  \
# 0    Friday                Brad Bird  action       Tomorrowland  22/05/2015
# 1    Friday              Scott Waugh  action     Need for Speed  14/03/2014
# 2    Friday           Patrick Hughes  action  The Expendables 3  15/08/2014
# 3    Friday  Phil Lord, Chris Miller  comedy     21 Jump Street  16/03/2012
# 4    Friday          Roland Emmerich  action   White House Down  28/06/2013
#
#                 Studio AdjustedGrossMillions  BudgetMillions GrossMillions  \
# 0  Buena Vista Studios                 202.1           170.0         202.1
# 1  Buena Vista Studios                 204.2            66.0         203.3
# 2            Lionsgate                 207.1           100.0         206.2
# 3                 Sony                 208.8            42.0         201.6
# 4                 Sony                 209.7           150.0         205.4
#
# ...

# %%
moviedata['ReleaseYear'] = pd.DatetimeIndex(moviedata['ReleaseDate']).year

# %%
moviedata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 608 entries, 0 to 607
# Data columns (total 19 columns):
# DayofWeek                608 non-null object
# Director                 608 non-null object
# Genre                    608 non-null object
# MovieTitle               608 non-null object
# ReleaseDate              608 non-null object
# Studio                   608 non-null object
# AdjustedGrossMillions    608 non-null object
# BudgetMillions           608 non-null float64
# GrossMillions            608 non-null object
# IMDbRating               608 non-null float64
# MovieLensRating          608 non-null float64
# OverseasMillions         608 non-null object
# OverseasPercent          608 non-null float64
# ProfitMillions           608 non-null object
# ProfitPercent            608 non-null float64
# RuntimeMinutes           608 non-null int64
# USMillions               608 non-null float64
# GrossPrecentUS           608 non-null float64
# ...

# %%
moviedata.describe()
# Out:
#        BudgetMillions  IMDbRating  MovieLensRating  OverseasPercent  \
# count      608.000000  608.000000       608.000000       608.000000
# mean        92.467928    6.923849         3.340378        57.698849
# std         59.421407    0.925890         0.454071        12.334237
# min          0.600000    3.600000         1.490000        17.200000
# 25%         45.000000    6.375000         3.037500        49.900000
# 50%         80.000000    6.900000         3.365000        58.200000
# 75%        130.000000    7.600000         3.672500        66.300000
# max        300.000000    9.200000         4.500000       100.000000
#
#        ProfitPercent  RuntimeMinutes  USMillions  GrossPrecentUS  ReleaseYear
# count     608.000000      608.000000  608.000000      608.000000   608.000000
# mean      719.278783      117.781250  167.135197       42.301151  2003.960526
# std      1942.807248       23.179122   92.465903       12.334237     9.091431
# ...

# %%
moviedata.ReleaseYear = moviedata.ReleaseYear.astype('category')
moviedata.Genre = moviedata.Genre.astype('category')
moviedata.MovieTitle  = moviedata.MovieTitle.astype('category')

# %%
moviedata.Studio.unique()
# Out:
# array(['Buena Vista Studios', 'Lionsgate', 'Sony', 'Universal',
#        'Paramount Pictures', 'WB', 'Weinstein Company',
#        'UA Entertainment', 'WB/New Line', 'New Line Cinema', 'Fox',
#        'TriStar', 'Relativity Media', 'Screen Gems', 'StudioCanal',
#        'Fox Searchlight Pictures', 'MiraMax', 'Path_ Distribution',
#        'DreamWorks', 'Lionsgate Films', 'Revolution Studios',
#        'Dimension Films', 'USA', 'Lionsgate/Summit',
#        'Sony Picture Classics', 'Pacific Data/DreamWorks', 'Disney',
#        'Art House Studios', 'Colombia Pictures', 'Gramercy Pictures',
#        'Summit Entertainment', 'Vestron Pictures', 'MGM', 'Orion', 'IFC',
#        'New Market Films'], dtype=object)

# %%
#moviedata.Genre.unique()
#w = sns.boxplot(data = moviedata, x = 'Genre', y = 'GrossPrecentUS')
#moviedata.Genre.cat.categories
#Genrelist = ['action', 'comedy', 'adventure', 'animation', 'drama']
#Studiolist = ['Buena Vista Studios', 'Sony','Universal','WB','Paramount Pictures','Fox' ]
#mylabel = []
#for gen in moviedata.Genre.cat.categories[[0, 4, 1, 2, 7]]:
   # list1.append

moviedatasubset = moviedata[(moviedata.Genre.isin(Genrelist)) & (moviedata.Studio.isin(Studiolist))]

#movidatasubset.Genre.unique()

mov2 = moviedata[moviedata.Genre.isin(Genrelist)]

# %%
len(moviedatasubset)
# Out:
# 423

# %%
mov3 = mov2[mov2.Studio.isin(Studiolist)]

# %%
len(mov3)
# Out:
# 423

# %%
w = sns.boxplot(data = moviedatasubset, x = 'Genre', y = 'GrossPrecentUS')
