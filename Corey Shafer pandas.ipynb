# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
from pandas import Series, DataFrame
# %matplotlib inline

# %%
df = pd.read_csv(r'C:\Users\Admin\Desktop\Python Training\developer_survey_2019\survey_results_public.csv')

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.shape
# Out:
# (88883, 85)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
# Respondent                88883 non-null int64
# MainBranch                88331 non-null object
# Hobbyist                  88883 non-null object
# OpenSourcer               88883 non-null object
# OpenSource                86842 non-null object
# Employment                87181 non-null object
# Country                   88751 non-null object
# Student                   87014 non-null object
# EdLevel                   86390 non-null object
# UndergradMajor            75614 non-null object
# EduOther                  84260 non-null object
# OrgSize                   71791 non-null object
# DevType                   81335 non-null object
# YearsCode                 87938 non-null object
# Age1stCode                87634 non-null object
# YearsCodePro              74331 non-null object
# CareerSat                 72847 non-null object
# ...

# %%
# if you want to see all columns
pd.set_option('display.max_columns', 85)

# %%
schema_df= pd.read_csv(r'C:\Users\Admin\Desktop\Python Training\developer_survey_2019\survey_results_schema.csv')

# %%
schema_df.head()
# Out:
#         Column                                       QuestionText
# 0   Respondent  Randomized respondent ID number (not in order ...
# 1   MainBranch  Which of the following options best describes ...
# 2     Hobbyist                            Do you code as a hobby?
# 3  OpenSourcer        How often do you contribute to open source?
# 4   OpenSource  How do you feel about the quality of open sour...

# %%
pd.set_option('display.max_rows', 85)

# %%
schema_df
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %%
# Learn how to select columns and Rows

people = {'first':['Corey', 'Jane', 'John']
                   , 'last': ['Schafer', 'Doe', 'Doe']
         , 'email': ['coreyshcafer@gmail.com','janedoe@gmail.com', 'johndoe@gmail.com']}

# %%
Peopledf = pd.DataFrame(people)

# %%
Peopledf
# Out:
#                     email  first     last
# 0  coreyshcafer@gmail.com  Corey  Schafer
# 1       janedoe@gmail.com   Jane      Doe
# 2       johndoe@gmail.com   John      Doe

# %%
Peopledf['email']
# Out:
# 0    coreyshcafer@gmail.com
# 1         janedoe@gmail.com
# 2         johndoe@gmail.com
# Name: email, dtype: object

# %%
people['email']
# Out:
# ['coreyshcafer@gmail.com', 'janedoe@gmail.com', 'johndoe@gmail.com']

# %%
type(Peopledf['email'])
# Out:
# pandas.core.series.Series

# %%
Peopledf.email
# Out:
# 0    coreyshcafer@gmail.com
# 1         janedoe@gmail.com
# 2         johndoe@gmail.com
# Name: email, dtype: object

# %%
Peopledf[['email', 'first']]
# Out:
#                     email  first
# 0  coreyshcafer@gmail.com  Corey
# 1       janedoe@gmail.com   Jane
# 2       johndoe@gmail.com   John

# %%
Peopledf.iloc[0]
# Out:
# email    coreyshcafer@gmail.com
# first                     Corey
# last                    Schafer
# Name: 0, dtype: object

# %%
Peopledf.iloc[[0,1], [2]]
# Out:
#       last
# 0  Schafer
# 1      Doe

# %%
Peopledf.loc[[0,1]]
# Out:
#                     email  first     last
# 0  coreyshcafer@gmail.com  Corey  Schafer
# 1       janedoe@gmail.com   Jane      Doe

# %%
Peopledf.loc[[0,1], ['email','first']]
# Out:
#                     email  first
# 0  coreyshcafer@gmail.com  Corey
# 1       janedoe@gmail.com   Jane

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df['Hobbyist'].value_counts() # give count of unique values
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df.Hobbyist.value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df.loc[0:2, 'Hobbyist': 'Employment']
# Out:
#   Hobbyist              OpenSourcer  \
# 0      Yes                    Never
# 1       No  Less than once per year
# 2      Yes                    Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
#
#                                Employment
# 0  Not employed, and not looking for work
# 1      Not employed, but looking for work
# 2                      Employed full-time

# %%
Peopledf.set_index('email', inplace = True)

# %%
Peopledf
# Out:
#                         first     last
# email
# coreyshcafer@gmail.com  Corey  Schafer
# janedoe@gmail.com        Jane      Doe
# johndoe@gmail.com        John      Doe

# %%
Peopledf.loc['janedoe@gmail.com', 'last']
# Out:
# 'Doe'

# %%
Peopledf = pd.DataFrame(people, index = ['coreyshcafer@gmail.com','janedoe@gmail.com','johndoe@gmail.com' ])

# %%
Peopledf
# Out:
#                         first     last
# email
# coreyshcafer@gmail.com  Corey  Schafer
# janedoe@gmail.com        Jane      Doe
# johndoe@gmail.com        John      Doe

# %%
Peopledf.reset_index(inplace = True)
Peopledf
# Out:
#                     email  first     last
# 0  coreyshcafer@gmail.com  Corey  Schafer
# 1       janedoe@gmail.com   Jane      Doe
# 2       johndoe@gmail.com   John      Doe

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
# Change index while laoding the file 

df = pd.read_csv(r'C:\Users\Admin\Desktop\Python Training\developer_survey_2019\survey_results_public.csv', index_col = 'Respondent')

# %%
schema_df.head()
# Out:
#                                                   QuestionText
# Column
# Respondent   Randomized respondent ID number (not in order ...
# MainBranch   Which of the following options best describes ...
# Hobbyist                               Do you code as a hobby?
# OpenSourcer        How often do you contribute to open source?
# OpenSource   How do you feel about the quality of open sour...

# %%
schema_df= pd.read_csv(r'C:\Users\Admin\Desktop\Python Training\developer_survey_2019\survey_results_schema.csv',index_col = 'Column' )

# %%
schema_df['QuestionText']
# Out:
# Column
# Respondent                Randomized respondent ID number (not in order ...
# MainBranch                Which of the following options best describes ...
# Hobbyist                                            Do you code as a hobby?
# OpenSourcer                     How often do you contribute to open source?
# OpenSource                How do you feel about the quality of open sour...
# Employment                Which of the following best describes your cur...
# Country                           In which country do you currently reside?
# Student                   Are you currently enrolled in a formal, degree...
# EdLevel                   Which of the following best describes the high...
# UndergradMajor            What was your main or most important field of ...
# EduOther                  Which of the following types of non-degree edu...
# OrgSize                   Approximately how many people are employed by ...
# ...

# %%
schema_df.loc['MgrIdiot', 'QuestionText'] # if you want to read entire text
# Out:
# 'How confident are you that your manager knows what they’re doing?'

# %%
schema_df.sort_index(ascending = False)
# Out:
#                                                              QuestionText
# Column
# YearsCodePro            How many years have you coded professionally (...
# YearsCode               Including any education, how many years have y...
# WorkWeekHrs              On average, how many hours per week do you work?
# WorkRemote                                How often do you work remotely?
# WorkPlan                          How structured or planned is your work?
# WorkLoc                                   Where would you prefer to work?
# WorkChallenge           Of these options, what are your greatest chall...
# WelcomeChange           Compared to last year, how welcome do you feel...
# WebFrameWorkedWith      Which of the following web frameworks have you...
# WebFrameDesireNextYear  Which of the following web frameworks have you...
# UnitTests               Does your company regularly employ unit tests ...
# UndergradMajor          What was your main or most important field of ...
# ...

# %%
Peopledf.set_index('email')
# Out:
#                         first     last
# email
# coreyshcafer@gmail.com  Corey  Schafer
# janedoe@gmail.com        Jane      Doe
# johndoe@gmail.com        John      Doe

# %%
# Playing with Filters

filt = (Peopledf['last'] == 'Doe')

# %%
# multiple ways of calling filters
#Peopledf[filt]
Peopledf[(Peopledf['last'] == 'Doe')]
# Out:
#                email first last
# 1  janedoe@gmail.com  Jane  Doe
# 2  johndoe@gmail.com  John  Doe

# %%
# using filter to select rows and columns

Peopledf.loc[(Peopledf['last'] == 'Doe'), 'email']
or
Peopledf.loc[filt, 'email']
# Out:
# 1    janedoe@gmail.com
# 2    johndoe@gmail.com
# Name: email, dtype: object

# %%
# & --- And
# | --- or
#Peopledf[(Peopledf['last'] == 'Doe') & (Peopledf['first'] == 'John')]
Peopledf.loc[(Peopledf['last'] == 'Doe') & (Peopledf['first'] == 'John'), 'email']

# or you can update filt variable
# Out:
# 2    johndoe@gmail.com
# Name: email, dtype: object

# %%
# OR operator example
Peopledf.loc[(Peopledf['last'] == 'Schafer') | (Peopledf['first'] == 'John'), 'email']
# Out:
# 0    coreyshcafer@gmail.com
# 2         johndoe@gmail.com
# Name: email, dtype: object

# %%
# negative filter (Adding a tilda ~ sign)
Peopledf.loc[~(Peopledf['last'] == 'Schafer') & ~(Peopledf['first'] == 'John'), 'email']
# Out:
# 1    janedoe@gmail.com
# Name: email, dtype: object

# %%
#df.head()

high_sal = (df['ConvertedComp'] > 70000)

# %%
df.loc[high_sal, ['Country', 'LanguageWorkedWith', 'ConvertedComp']]
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 6                   Canada                                         Java;R;SQL
# 9              New Zealand  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 13           United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 16          United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 22           United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# 26           United States  Bash/Shell/PowerShell;C++;C#;HTML/CSS;JavaScri...
# 29           United States               Bash/Shell/PowerShell;JavaScript;SQL
# 30             Switzerland                                                NaN
# 32           United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 35           United States                                HTML/CSS;JavaScript
# 39           United States                       C#;JavaScript;SQL;TypeScript
# ...

# %%
countries = ['United States', 'India', 'United Kingdom', 'Germany', 'Canada']
count_filt = df['Country'].isin(countries)

# %%
df.loc[(high_sal) & (count_filt), ['Country', 'LanguageWorkedWith', 'ConvertedComp']]
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 6                   Canada                                         Java;R;SQL
# 13           United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 16          United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 22           United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# 26           United States  Bash/Shell/PowerShell;C++;C#;HTML/CSS;JavaScri...
# 29           United States               Bash/Shell/PowerShell;JavaScript;SQL
# 32           United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 35           United States                                HTML/CSS;JavaScript
# 39           United States                       C#;JavaScript;SQL;TypeScript
# 44                 Germany  Bash/Shell/PowerShell;C#;HTML/CSS;Java;JavaScr...
# 45           United States                                             Python
# ...

# %%
df['LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 3                                                 HTML/CSS
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 6                                               Java;R;SQL
# 7                                      HTML/CSS;JavaScript
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 9        Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 10                           C#;Go;JavaScript;Python;R;SQL
# 11                                               Other(s):
# 12        Bash/Shell/PowerShell;HTML/CSS;Java;Python;R;SQL
# 13       Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 14                                                     C++
# 15       Assembly;Bash/Shell/PowerShell;C;C++;HTML/CSS;...
# 16       Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# ...

# %%
# how to get a string subset

lang_fit = df['LanguageWorkedWith'].str.contains('Python', na = False)

# %%
df.loc[(high_sal) & (count_filt) & (lang_fit) , ['Country', 'LanguageWorkedWith', 'ConvertedComp']]
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 22           United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# 26           United States  Bash/Shell/PowerShell;C++;C#;HTML/CSS;JavaScri...
# 32           United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 45           United States                                             Python
# 60           United States  Bash/Shell/PowerShell;Go;JavaScript;PHP;Python...
# 82          United Kingdom  Bash/Shell/PowerShell;C++;HTML/CSS;Java;JavaSc...
# 95           United States                C#;HTML/CSS;JavaScript;Python;R;SQL
# 106          United States  Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# 108          United States                                         C++;Python
# 110          United States                                         Python;SQL
# 127          United States                     Bash/Shell/PowerShell;C;Python
# ...

# %%
df.loc[(high_sal) & (count_filt) & (lang_fit) , 'LanguageWorkedWith']
# Out:
# Respondent
# 22       Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# 26       Bash/Shell/PowerShell;C++;C#;HTML/CSS;JavaScri...
# 32       Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 45                                                  Python
# 60       Bash/Shell/PowerShell;Go;JavaScript;PHP;Python...
# 82       Bash/Shell/PowerShell;C++;HTML/CSS;Java;JavaSc...
# 95                     C#;HTML/CSS;JavaScript;Python;R;SQL
# 106      Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# 108                                             C++;Python
# 110                                             Python;SQL
# 127                         Bash/Shell/PowerShell;C;Python
# 132      Bash/Shell/PowerShell;C++;C#;HTML/CSS;Java;Jav...
# 143       C;HTML/CSS;Java;JavaScript;Python;SQL;TypeScript
# 202      Bash/Shell/PowerShell;C;C++;C#;HTML/CSS;Java;J...
# 209      Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 210         C++;Go;Java;JavaScript;Python;Rust;WebAssembly
# ...

# %%
Peopledf.columns
# Out:
# Index(['email', 'first_name', 'last_name'], dtype='object')

# %%
Peopledf.columns = ['email', 'first_name', 'last_name']

# %%
# how to change only one column using list compresension

Peopledf.columns = [x.lower() for x in Peopledf.columns]

# %%
Peopledf.columns
# Out:
# Index(['email', 'first', 'last'], dtype='object')

# %%
# Change one column
#Peopledf.columns = Peopledf.columns.str.replace('FIRST_NAME', 'First_Name')

#or use rename

Peopledf.rename(columns= {'first_name': 'first', 'last_name': 'last'}, inplace = True)

# %%
# Update data in rows

Peopledf.loc[2] = ['johnsmith@gmail.com','John', 'Smith']

# %%
Peopledf.loc[2]
# Out:
# email    johndoe@gmail.com
# first                 John
# last                   Doe
# Name: 2, dtype: object

# %%
# how to change few columns in a row

Peopledf.loc[2, ['email', 'last']] = ['johndoe@gmail.com', 'Doe']

# %%
Peopledf.loc[2, 'last'] =  'Smith'  # changing one row one column

# %%
# using at

Peopledf.at[2,'last'] = 'Doe'

# %%
df.loc[2]
# Out:
# MainBranch                           I am a student who is learning to code
# Hobbyist                                                                 No
# OpenSourcer                                         Less than once per year
# OpenSource                The quality of OSS and closed source software ...
# Employment                               Not employed, but looking for work
# Country                                              Bosnia and Herzegovina
# Student                                                      Yes, full-time
# EdLevel                   Secondary school (e.g. American high school, G...
# UndergradMajor                                                          NaN
# EduOther                  Taken an online course in programming or softw...
# OrgSize                                                                 NaN
# DevType                   Developer, desktop or enterprise applications;...
# ...

# %%
name_flit = (Peopledf['email']== 'johndoe@gmail.com')

# %%
Peopledf[name_flit]
# Out:
#                email first last
# 2  johndoe@gmail.com  John  Doe

# %%
# using filter to change values in rows

Peopledf.loc[name_flit, 'last']= 'Smith'

# %%
Peopledf
# Out:
#                     email  first     last
# 0  COREYSHCAFER@GMAIL.COM  Corey  Schafer
# 1       JANEDOE@GMAIL.COM   Jane      Doe
# 2       JOHNDOE@GMAIL.COM   John    Smith

# %%
# How to update Multiple rows

Peopledf['email'].str.upper()
# Out:
# 0    COREYSHCAFER@GMAIL.COM
# 1         JANEDOE@GMAIL.COM
# 2         JOHNDOE@GMAIL.COM
# Name: email, dtype: object

# %%
Peopledf['email'] = Peopledf['email'].str.upper()

# %% [markdown]
# # 4 main methods of replacing data
#
# apply
# map
# applymap
# replace

# %%
Peopledf['email'].apply(len) # on series object
# Out:
# 0    22
# 1    17
# 2    17
# Name: email, dtype: int64

# %%
Peopledf
# Out:
#                     email  first     last
# 0  COREYSHCAFER@GMAIL.COM  Corey  Schafer
# 1       JANEDOE@GMAIL.COM   Jane      Doe
# 2       JOHNDOE@GMAIL.COM   John    Smith

# %%
def update_email(email):
    return email.lower()

# %%
Peopledf['email'].apply(update_email)
# Out:
# 0    coreyshcafer@gmail.com
# 1         janedoe@gmail.com
# 2         johndoe@gmail.com
# Name: email, dtype: object

# %%
Peopledf['email'] = Peopledf['email'].apply(update_email)

# %%
Peopledf['email'] = Peopledf['email'].apply(lambda x: x.upper())

# %%
# apply on data frame

#Peopledf['email'].apply(len)

Peopledf.apply(len) #only gives me the # of rows in each column same as len(Peopledf['email])
# Out:
# email    3
# first    3
# last     3
# dtype: int64

# %%
Peopledf.apply(pd.Series.min)
# Out:
# email    COREYSHCAFER@GMAIL.COM
# first                     Corey
# last                        Doe
# dtype: object

# %%
Peopledf.apply(lambda x:x.min())
# Out:
# email    COREYSHCAFER@GMAIL.COM
# first                     Corey
# last                        Doe
# dtype: object

# %%
Peopledf.applymap(len)
# Out:
#    email  first  last
# 0     22      5     7
# 1     17      4     3
# 2     17      4     5

# %%
Peopledf.apply(len)
# Out:
# email    3
# first    3
# last     3
# dtype: int64

# %%
Peopledf.applymap(str.lower)
# Out:
#                     email  first     last
# 0  coreyshcafer@gmail.com  corey  schafer
# 1       janedoe@gmail.com   jane      doe
# 2       johndoe@gmail.com   john    smith

# %%
Peopledf['first'].map({'Corey': 'Chris', 'Jane': 'Mary'}) # map changes the missing value to none; John becomes NAN
# Out:
# 0    Chris
# 1     Mary
# 2      NaN
# Name: first, dtype: object

# %%
Peopledf['first'] = Peopledf['first'].replace({'Corey': 'Chris', 'Jane': 'Mary'})

# %%
Peopledf
# Out:
#                     email  first     last
# 0  COREYSHCAFER@GMAIL.COM  Chris  Schafer
# 1       JANEDOE@GMAIL.COM   Mary      Doe
# 2       JOHNDOE@GMAIL.COM   John    Smith

# %%
#df
#schema_df
df.rename(columns = {'ConvertedComp': 'SalaryUSD'}, inplace = True)
df.head()
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      True
# 2                      I am a student who is learning to code     False
# 3           I am not primarily a developer, but I write co...      True
# 4                              I am a developer by profession     False
# 5                              I am a developer by profession      True
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df['Hobbyist'] = df['Hobbyist'].map({'Yes': True, 'No': False})

# %%
df['Hobbyist'].value_counts()
# Out:
# True     71257
# False    17626
# Name: Hobbyist, dtype: int64

# %%
Peopledf
# Out:
#                     email  first     last
# 0  COREYSHCAFER@GMAIL.COM  Chris  Schafer
# 1       JANEDOE@GMAIL.COM   Mary      Doe
# 2       JOHNDOE@GMAIL.COM   John    Smith

# %%
Peopledf['first'] + ' '+ Peopledf['last']
# Out:
# 0    Chris Schafer
# 1         Mary Doe
# 2       John Smith
# dtype: object

# %% [markdown]
# # Adding and removing columns

# %%
Peopledf['full name']= Peopledf['first'] + ' '+ Peopledf['last'] # Add columns

# %%
Peopledf
# Out:
#                     email  first     last      full name
# 0  COREYSHCAFER@GMAIL.COM  Chris  Schafer  Chris Schafer
# 1       JANEDOE@GMAIL.COM   Mary      Doe       Mary Doe
# 2       JOHNDOE@GMAIL.COM   John    Smith     John Smith

# %%
Peopledf.drop(columns = ['first', 'last'], inplace = True)

# %%
Peopledf['full name'].str.split( expand = True) # how to split columns
# Out:
#        0        1
# 0  Chris  Schafer
# 1   Mary      Doe
# 2   John    Smith

# %%
Peopledf[['first', 'last']] =Peopledf['full name'].str.split( expand = True)

# %%
Peopledf
# Out:
#                     email      full name  first     last
# 0  COREYSHCAFER@GMAIL.COM  Chris Schafer  Chris  Schafer
# 1       JANEDOE@GMAIL.COM       Mary Doe   Mary      Doe
# 2       JOHNDOE@GMAIL.COM     John Smith   John    Smith

# %% [markdown]
# # Adding and removing rows

# %%
Peopledf.append({'first':'Tony'}, ignore_index = True)
# Out:
#                     email      full name  first     last
# 0  COREYSHCAFER@GMAIL.COM  Chris Schafer  Chris  Schafer
# 1       JANEDOE@GMAIL.COM       Mary Doe   Mary      Doe
# 2       JOHNDOE@GMAIL.COM     John Smith   John    Smith
# 3                     NaN            NaN   Tony      NaN

# %%
people = {'first':['Tony', 'Steve']
         , 'last': ['Stark', 'Rogers']
         , 'email': ['IronMan@avenge.com','Cap@avenge.com']}
Peopledf1 = pd.DataFrame(people, columns = ['email', 'first', 'last'])

# %%
Peopledf1
# Out:
#                 email  first    last
# 0  IronMan@avenge.com   Tony   Stark
# 1      Cap@avenge.com  Steve  Rogers

# %%
Peopledf.append(Peopledf1, ignore_index = True)
# Out:
#                     email  first      full name     last
# 0  COREYSHCAFER@GMAIL.COM  Chris  Chris Schafer  Schafer
# 1       JANEDOE@GMAIL.COM   Mary       Mary Doe      Doe
# 2       JOHNDOE@GMAIL.COM   John     John Smith    Smith
# 3      IronMan@avenge.com   Tony            NaN    Stark
# 4          Cap@avenge.com  Steve            NaN   Rogers

# %%
Peopledf = Peopledf.append(Peopledf1, ignore_index = True)

# %%
Peopledf
# Out:
#                     email  first      full name     last
# 0  COREYSHCAFER@GMAIL.COM  Chris  Chris Schafer  Schafer
# 1       JANEDOE@GMAIL.COM   Mary       Mary Doe      Doe
# 2       JOHNDOE@GMAIL.COM   John     John Smith    Smith
# 3      IronMan@avenge.com   Tony            NaN    Stark
# 4          Cap@avenge.com  Steve            NaN   Rogers

# %%
Peopledf.drop(index = 4)
# Out:
#                     email  first      full name     last
# 0  COREYSHCAFER@GMAIL.COM  Chris  Chris Schafer  Schafer
# 1       JANEDOE@GMAIL.COM   Mary       Mary Doe      Doe
# 2       JOHNDOE@GMAIL.COM   John     John Smith    Smith
# 3      IronMan@avenge.com   Tony            NaN    Stark

# %%
Peopledf.drop(index = Peopledf[Peopledf['last']== 'Doe'].index )
# Out:
#                     email  first      full name     last
# 0  COREYSHCAFER@GMAIL.COM  Chris  Chris Schafer  Schafer
# 2       JOHNDOE@GMAIL.COM   John     John Smith    Smith
# 3      IronMan@avenge.com   Tony            NaN    Stark
# 4          Cap@avenge.com  Steve            NaN   Rogers

# %%
filt = Peopledf['last']== 'Doe'

# %%
Peopledf.drop(index = Peopledf[filt].index )
# Out:
#                     email  first      full name     last
# 0  COREYSHCAFER@GMAIL.COM  Chris  Chris Schafer  Schafer
# 2       JOHNDOE@GMAIL.COM   John     John Smith    Smith
# 3      IronMan@avenge.com   Tony            NaN    Stark
# 4          Cap@avenge.com  Steve            NaN   Rogers

# %% [markdown]
# # Sorting of Values

# %%
Peopledf.sort_values(by = 'last', ascending = False)
# Out:
#                     email  first     last
# 0  coreyshcafer@gmail.com  Corey  Schafer
# 1       janedoe@gmail.com   Jane      Doe
# 2       johndoe@gmail.com   John      Doe

# %%
Peopledf.sort_values(by = ['last','first'], ascending = False)
# Out:
#                     email  first     last
# 0  coreyshcafer@gmail.com  Corey  Schafer
# 2       johndoe@gmail.com   John      Doe
# 1       janedoe@gmail.com   Jane      Doe

# %%
Peopledf = Peopledf.append({'email': 'a@gmail.com', 'first': 'Adam', 'last': 'Doe'}, ignore_index=True)

# %%
Peopledf
# Out:
#                     email  first     last
# 0  coreyshcafer@gmail.com  Corey  Schafer
# 1       janedoe@gmail.com   Jane      Doe
# 2       johndoe@gmail.com   John      Doe
# 3             a@gmail.com   Adam      Doe

# %%
Peopledf.sort_values(by = ['last','first'], ascending = [False, True])
# Out:
#                     email  first     last
# 0  coreyshcafer@gmail.com  Corey  Schafer
# 3             a@gmail.com   Adam      Doe
# 1       janedoe@gmail.com   Jane      Doe
# 2       johndoe@gmail.com   John      Doe

# %%
Peopledf.sort_index() # sort by index
# Out:
#                     email  first     last
# 0  coreyshcafer@gmail.com  Corey  Schafer
# 1       janedoe@gmail.com   Jane      Doe
# 2       johndoe@gmail.com   John      Doe
# 3             a@gmail.com   Adam      Doe

# %%
# sort a single column (series)

Peopledf['last'].sort_values()
# Out:
# 1        Doe
# 2        Doe
# 3        Doe
# 0    Schafer
# Name: last, dtype: object

# %%
df.head(50)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 39258                          I am a developer by profession      Yes
# 63129                          I am a developer by profession      Yes
# 85715                          I am a developer by profession       No
# 50767                          I am a developer by profession       No
# 2782                                                      NaN      Yes
# 63019                                                     NaN       No
# 6417                   I am a student who is learning to code      Yes
# 40000                  I am a student who is learning to code      Yes
# 88731                             I code primarily as a hobby      Yes
# 48436                          I am a developer by profession       No
# 10746                          I am a developer by profession      Yes
# 62525                  I am a student who is learning to code      Yes
# ...

# %%
df.sort_values(by = 'Country', inplace = True)

# %%
df[['Country', 'ConvertedComp']].head(50)
# Out:
#                 Country  ConvertedComp
# Respondent
# 63129       Afghanistan      1000000.0
# 50499       Afghanistan       153216.0
# 39258       Afghanistan        19152.0
# 58450       Afghanistan        17556.0
# 7085        Afghanistan        14364.0
# 22450       Afghanistan         7980.0
# 48436       Afghanistan         4464.0
# 10746       Afghanistan         3996.0
# 8149        Afghanistan         1596.0
# 29736       Afghanistan         1116.0
# 28638       Afghanistan            0.0
# 722         Afghanistan            0.0
# 85715       Afghanistan            NaN
# 50767       Afghanistan            NaN
# 2782        Afghanistan            NaN
# 63019       Afghanistan            NaN
# 6417        Afghanistan            NaN
# 40000       Afghanistan            NaN
# 88731       Afghanistan            NaN
# 62525       Afghanistan            NaN
# 49702       Afghanistan            NaN
# 33178       Afghanistan            NaN
# 60946       Afghanistan            NaN
# ...

# %%
df.sort_values(by = ['Country','ConvertedComp'] , ascending = [True, False], inplace = True)

# %%
# grab 10 largest salary

df['ConvertedComp'].nlargest(10)
# Out:
# Respondent
# 25983    2000000.0
# 87896    2000000.0
# 22013    2000000.0
# 28243    2000000.0
# 72732    2000000.0
# 78151    2000000.0
# 80200    2000000.0
# 52132    2000000.0
# 75561    2000000.0
# 32250    2000000.0
# Name: ConvertedComp, dtype: float64

# %%
df.nlargest(10,'ConvertedComp' )
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 25983                          I am a developer by profession      Yes
# 87896                          I am a developer by profession      Yes
# 22013                          I am a developer by profession      Yes
# 28243                          I am a developer by profession      Yes
# 72732       I am not primarily a developer, but I write co...       No
# 78151                          I am a developer by profession      Yes
# 80200                          I am a developer by profession      Yes
# 52132                          I am a developer by profession      Yes
# 75561                          I am a developer by profession      Yes
# 32250                          I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 25983                                 Less than once per year
# ...

# %%
df.nsmallest(10,'ConvertedComp' )
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 28638                          I am a developer by profession      Yes
# 722                            I am a developer by profession       No
# 13825                          I am a developer by profession      Yes
# 40913                          I am a developer by profession      Yes
# 30630                          I am a developer by profession      Yes
# 69049                          I am a developer by profession       No
# 19340       I am not primarily a developer, but I write co...      Yes
# 16214       I am not primarily a developer, but I write co...      Yes
# 29355                          I am a developer by profession      Yes
# 1685                           I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 28638       Less than once a month but more than once per ...
# ...

# %% [markdown]
# # Grouping and Aggregation

# %%
df['ConvertedComp'].median()   # median on single column
# Out:
# 57287.0

# %%
df.median() # on the entire data frame
# Out:
# CompTotal        62000.0
# ConvertedComp    57287.0
# WorkWeekHrs         40.0
# CodeRevHrs           4.0
# Age                 29.0
# dtype: float64

# %%
df.describe() # on entire data frame
# Out:
#           CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs           Age
# count  5.594500e+04   5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11   1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13   2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00   0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04   2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04   5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05   1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16   2.000000e+06   4850.000000     99.000000     99.000000

# %%
df['ConvertedComp'].describe() # for a single column
# Out:
# count    5.582300e+04
# mean     1.271107e+05
# std      2.841523e+05
# min      0.000000e+00
# 25%      2.577750e+04
# 50%      5.728700e+04
# 75%      1.000000e+05
# max      2.000000e+06
# Name: ConvertedComp, dtype: float64

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df['SocialMedia']
# Out:
# Respondent
# 63129    I don't use social media
# 50499                    WhatsApp
# 39258                    Facebook
# 58450                    Facebook
# 7085                    Instagram
# 22450                    Facebook
# 48436                    Facebook
# 10746                     YouTube
# 8149                     Facebook
# 29736                         NaN
# 28638                         NaN
# 722                           NaN
# 85715                    Facebook
# 50767                         NaN
# 2782     I don't use social media
# 63019                    LinkedIn
# 6417                     Facebook
# 40000                    WhatsApp
# 88731                     YouTube
# 62525                    Facebook
# 49702                         NaN
# 33178    I don't use social media
# 60946                    Facebook
# 86362                    WhatsApp
# 88582    I don't use social media
# 26340                    Facebook
# 86932                     Twitter
# ...

# %%
schema_df.loc['SocialMedia']
# Out:
# QuestionText    What social media site do you use the most?
# Name: SocialMedia, dtype: object

# %%
df['SocialMedia'].value_counts()
# Out:
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: SocialMedia, dtype: int64

# %%
#if you want to see it as a %
df['SocialMedia'].value_counts(normalize = True)
# Out:
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: SocialMedia, dtype: float64

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('India')
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 22013                          I am a developer by profession      Yes
# 28243                          I am a developer by profession      Yes
# 72732       I am not primarily a developer, but I write co...       No
# 80923                          I am a developer by profession      Yes
# 78265                          I am a developer by profession      Yes
# 16793                          I am a developer by profession      Yes
# 52561                          I am a developer by profession      Yes
# 53840                          I am a developer by profession      Yes
# 64181                          I am a developer by profession       No
# 76711                          I am a developer by profession      Yes
# 56055                          I am a developer by profession       No
# 32536                          I am a developer by profession      Yes
# ...

# %%
filt = df['Country'] == 'United States'
df.loc[filt]['SocialMedia'].value_counts()
# Out:
# Reddit                      5700
# Twitter                     3468
# Facebook                    2844
# YouTube                     2463
# I don't use social media    1851
# Instagram                   1652
# LinkedIn                    1020
# WhatsApp                     609
# Snapchat                     326
# WeChat 微信                     93
# VK ВКонта́кте                  9
# Weibo 新浪微博                     8
# Hello                          2
# Youku Tudou 优酷                 1
# Name: SocialMedia, dtype: int64

# %%
country_grp['SocialMedia'].value_counts().head(50)
# Out:
# Country              SocialMedia
# Afghanistan          Facebook                     15
#                      YouTube                       9
#                      I don't use social media      6
#                      WhatsApp                      4
#                      Instagram                     1
#                      LinkedIn                      1
#                      Twitter                       1
# Albania              WhatsApp                     18
#                      Facebook                     16
#                      Instagram                    13
#                      YouTube                      10
#                      Twitter                       8
#                      LinkedIn                      7
#                      Reddit                        6
#                      I don't use social media      4
#                      Snapchat                      1
#                      WeChat 微信                     1
# ...

# %%
country_grp['SocialMedia'].value_counts(normalize = True).loc['Russian Federation']
# Out:
# SocialMedia
# VK ВКонта́кте               0.303571
# YouTube                     0.207418
# I don't use social media    0.106456
# Reddit                      0.096154
# Twitter                     0.089286
# Instagram                   0.064560
# WhatsApp                    0.061813
# Facebook                    0.046016
# LinkedIn                    0.024038
# Snapchat                    0.000687
# Name: SocialMedia, dtype: float64

# %%
country_grp['ConvertedComp'].median()
# Out:
# Country
# Afghanistan                                    6222.0
# Albania                                       10818.0
# Algeria                                        7878.0
# Andorra                                      160931.0
# Angola                                         7764.0
# Antigua and Barbuda                               NaN
# Argentina                                     17760.0
# Armenia                                       19692.0
# Australia                                     79783.0
# Austria                                       51559.0
# Azerbaijan                                    15858.0
# Bahamas                                           NaN
# Bahrain                                       15912.0
# Bangladesh                                     8764.0
# Barbados                                      21000.0
# Belarus                                       24000.0
# Belgium                                       48120.0
# ...

# %%
# use Agg method to pass multiple aggregations

country_grp['ConvertedComp'].agg(['median', 'mean'])
# Out:
#                                              median           mean
# Country
# Afghanistan                                  6222.0  101953.333333
# Albania                                     10818.0   21833.700000
# Algeria                                      7878.0   34924.047619
# Andorra                                    160931.0  160931.000000
# Angola                                       7764.0    7764.000000
# Antigua and Barbuda                             NaN            NaN
# Argentina                                   17760.0   29467.265306
# Armenia                                     19692.0   24691.733333
# Australia                                   79783.0  171541.116279
# Austria                                     51559.0   83955.639604
# Azerbaijan                                  15858.0   15785.750000
# Bahamas                                         NaN            NaN
# Bahrain                                     15912.0   23934.000000
# ...

# %%
# by single index

country_grp['ConvertedComp'].agg(['median', 'mean']).loc['Canada']
# Out:
# median     68705.000000
# mean      134018.564909
# Name: Canada, dtype: float64

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()  # using filters to use agg functions
# Out:
# 3105

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum()) # using grp to get values
# Out:
# Country
# Afghanistan                                      8
# Albania                                         23
# Algeria                                         40
# Andorra                                          0
# Angola                                           2
# Antigua and Barbuda                              0
# Argentina                                      191
# Armenia                                         28
# Australia                                      790
# Austria                                        338
# Azerbaijan                                      17
# Bahamas                                          2
# Bahrain                                          4
# Bangladesh                                     204
# Barbados                                         1
# Belarus                                         69
# Belgium                                        296
# Belize                                           1
# ...

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())/df['Country'].value_counts()
# Out:
# Afghanistan                                  0.181818
# Albania                                      0.267442
# Algeria                                      0.298507
# Andorra                                      0.000000
# Angola                                       0.400000
# Antigua and Barbuda                          0.000000
# Argentina                                    0.345389
# Armenia                                      0.325581
# Australia                                    0.415134
# Austria                                      0.402861
# Azerbaijan                                   0.346939
# Bahamas                                      0.666667
# Bahrain                                      0.222222
# Bangladesh                                   0.337190
# Barbados                                     0.333333
# Belarus                                      0.341584
# Belgium                                      0.407153
# ...

# %%
#Corey's method
country_uses_python = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_respondents = df['Country'].value_counts()

# %%
python_df = pd.concat([country_respondents,country_uses_python], axis = 'columns')

# %%
python_df.rename(columns = {'Country': 'NumRespondents', 'LanguageWorkedWith': 'NumKnowsPython'}, inplace = True)

# %%
python_df['PctKnowsPyhton'] = (python_df['NumKnowsPython']/python_df['NumRespondents']) *100

# %%
python_df.sort_values(by = 'PctKnowsPyhton', ascending = False, inplace = True)

# %%
python_df.loc['Japan']
# Out:
# NumRespondents    391.000000
# NumKnowsPython    182.000000
# PctKnowsPyhton     46.547315
# Name: Japan, dtype: float64
